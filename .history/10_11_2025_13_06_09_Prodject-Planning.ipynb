# %%
suppressPackageStartupMessages(
    {suppressWarnings({
        install.packages("formatR")
        library(formatR)
        library(tidyverse)
        library(repr)
        library(tidymodels)
        library(GGally)
    })
})

options(repr.plot.width = 6, repr.plot.height = 4, repr.matrix.max.rows = 6)

# %%
options(readr.show_col_types = FALSE)
player_data <- read_csv("data/players.csv")
session_data <- read_csv("data/sessions.csv")

ply_rows <- nrow(player_data)
ply_rows
str(player_data)

# %% [markdown]
# # **Data Science Project: Planning Stage (Individual)**
#
# ### **(1) Data Description:**
#  To answer ... question from.... UBC computer ..
#  Source and collection of data ...
#
#  #### **Player Data:**
# > This data set .... serves to.... . In our player data, there are <y> number of observations, <x> variables.
# >
# > Our variables from the player dataset:
# > - `tmp` ...
# >
# > Summary Statistic:
# > - mean ...
# >
# > Potential data issues:
# > - some ...
# >
# >
#
#  #### **Session Data:**
# > This data set .... serves to.... . In our player data, there are <y> number of observations, <x> variables.
# >
# > Our variables from the player dataset:
# > - `tmp` ...
# >
# > Summary Statistic:
# > - mean ...
# >
# > Potential data issues:
# > - some ...
# >
# >
#
# ### **(2) Questions:**
#
# ### **(3) Exploratory Data Analysis and Visualization:**
#
# ### **(4) Methods and Plan**
